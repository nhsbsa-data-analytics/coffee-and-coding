# %% [markdown]
# # Load Packages and Data

# %%
import datetime
import pandas as pd

# %% [markdown]
# Said in the last session that Pandas can pretty much do everything which shows here
#
# Will be going over data cleaning, using ...

# %%
data = pd.read_csv('data_raw.csv')

data
# Out:
#      Survey Date What is your age? What is your gender?  \
# 0     01/01/2022                39                 Male
# 1     01/01/2022                28                 Male
# 2     01/01/2022                26                 Male
# 3     01/01/2022                32           non-binary
# 4     01/01/2022                34                 Male
# ...          ...               ...                  ...
# 1428  10/01/2022                39                 male
# 1429  10/01/2022                28                 Male
# 1430  10/01/2022                36                 Male
# 1431  10/01/2022                41                 male
# 1432  10/01/2022                56                 MALE
#
#       Are you self-employed?  \
# 0                          0
# 1                          0
# 2                          0
# 3                          0
# 4                          1
# ...                      ...
# 1428                       0
# 1429                       0
# 1430                       0
# 1431                       0
# 1432                       1
#
#       How many years have you worked for your current organization (or been self employed)?  \
# 0                                                 13.50
# 1                                                 15.49
# 2                                                 19.41
# 3                                                  6.90
# 4                                                  9.92
# ...                                                 ...
# 1428                                               3.37
# 1429                                              10.65
# 1430                                               9.18
# 1431                                              10.44
# 1432                                              21.20
#
#      How many employees does your company or organization have?  \
# 0                                                26-100
# 1                                                26-100
# 2                                   2025-06-01 00:00:00
# 3                                               100-500
# 4                                                   NaN
# ...                                                 ...
# 1428                                     More than 1000
# 1429                                            100-500
# 1430                                            100-500
# 1431                                     More than 1000
# 1432                                                NaN
#
#      Do you currently have a mental health disorder?  \
# 0                                                 No
# 1                                                Yes
# 2                                                 No
# 3                                                Yes
# 4                                                Yes
# ...                                              ...
# 1428                                              No
# 1429                                             Yes
# 1430                                             Yes
# 1431                                             Yes
# 1432                                              No
#
#      If yes, what condition(s) have you been diagnosed with?
# 0                                                   NaN
# 1     Mood Disorder (Depression, Bipolar Disorder, etc)
# 2                                                   NaN
# 3     Mood Disorder (Depression, Bipolar Disorder, etc)
# 4     Mood Disorder (Depression, Bipolar Disorder, e...
# ...                                                 ...
# 1428                                                NaN
# 1429  Anxiety Disorder (Generalized, Social, Phobia,...
# 1430  Mood Disorder (Depression, Bipolar Disorder, etc)
# 1431           Attention Deficit Hyperactivity Disorder
# 1432                                                NaN
#
# [1433 rows x 8 columns]

# %%
data.dtypes
# Out:
# Survey Date                                                                               object
# What is your age?                                                                         object
# What is your gender?                                                                      object
# Are you self-employed?                                                                     int64
# How many years have you worked for your current organization (or been self employed)?    float64
# How many employees does your company or organization have?                                object
# Do you currently have a mental health disorder?                                           object
# If yes, what condition(s) have you been diagnosed with?                                   object
# dtype: object

# %% [markdown]
# 1) Names are ugly (explain why there is a problem)
# 2) Notice errors (date in bad format, dates in number of employees, gender has multiple encodings for male)
# 3) NULLS
# 4) Wrong format with dtypes

# %% [markdown]
# # Rename Columns

# %%
columns = ['survey_date', 
           'age', 
           'gender', 
           'self_employed',
           'years_employed',
           'number_of_employees', 
           'has_mental_health', 
           'conditions']

data.columns = columns

# %%
data
# Out:
#      survey_date age      gender  self_employed  years_employed  \
# 0     01/01/2022  39        Male              0           13.50
# 1     01/01/2022  28        Male              0           15.49
# 2     01/01/2022  26        Male              0           19.41
# 3     01/01/2022  32  non-binary              0            6.90
# 4     01/01/2022  34        Male              1            9.92
# ...          ...  ..         ...            ...             ...
# 1428  10/01/2022  39        male              0            3.37
# 1429  10/01/2022  28        Male              0           10.65
# 1430  10/01/2022  36        Male              0            9.18
# 1431  10/01/2022  41        male              0           10.44
# 1432  10/01/2022  56        MALE              1           21.20
#
#       number_of_employees has_mental_health  \
# 0                  26-100                No
# 1                  26-100               Yes
# 2     2025-06-01 00:00:00                No
# 3                 100-500               Yes
# 4                     NaN               Yes
# ...                   ...               ...
# 1428       More than 1000                No
# 1429              100-500               Yes
# 1430              100-500               Yes
# 1431       More than 1000               Yes
# 1432                  NaN                No
#
#                                              conditions
# 0                                                   NaN
# 1     Mood Disorder (Depression, Bipolar Disorder, etc)
# 2                                                   NaN
# 3     Mood Disorder (Depression, Bipolar Disorder, etc)
# 4     Mood Disorder (Depression, Bipolar Disorder, e...
# ...                                                 ...
# 1428                                                NaN
# 1429  Anxiety Disorder (Generalized, Social, Phobia,...
# 1430  Mood Disorder (Depression, Bipolar Disorder, etc)
# 1431           Attention Deficit Hyperactivity Disorder
# 1432                                                NaN
#
# [1433 rows x 8 columns]

# %% [markdown]
# # Convert Data Types

# %%
data['survey_date'] =  pd.to_datetime(data['survey_date'], format='%d/%m/%Y')
data['self_employed'] = data['self_employed'].astype('bool')

# %%
# data['age'] = data['age'].astype(int)

# %%
data
# Out:
#      survey_date age      gender  self_employed  years_employed  \
# 0     2022-01-01  39        Male          False           13.50
# 1     2022-01-01  28        Male          False           15.49
# 2     2022-01-01  26        Male          False           19.41
# 3     2022-01-01  32  non-binary          False            6.90
# 4     2022-01-01  34        Male           True            9.92
# ...          ...  ..         ...            ...             ...
# 1428  2022-01-10  39        male          False            3.37
# 1429  2022-01-10  28        Male          False           10.65
# 1430  2022-01-10  36        Male          False            9.18
# 1431  2022-01-10  41        male          False           10.44
# 1432  2022-01-10  56        MALE           True           21.20
#
#       number_of_employees has_mental_health  \
# 0                  26-100                No
# 1                  26-100               Yes
# 2     2025-06-01 00:00:00                No
# 3                 100-500               Yes
# 4                     NaN               Yes
# ...                   ...               ...
# 1428       More than 1000                No
# 1429              100-500               Yes
# 1430              100-500               Yes
# 1431       More than 1000               Yes
# 1432                  NaN                No
#
#                                              conditions
# 0                                                   NaN
# 1     Mood Disorder (Depression, Bipolar Disorder, etc)
# 2                                                   NaN
# 3     Mood Disorder (Depression, Bipolar Disorder, etc)
# 4     Mood Disorder (Depression, Bipolar Disorder, e...
# ...                                                 ...
# 1428                                                NaN
# 1429  Anxiety Disorder (Generalized, Social, Phobia,...
# 1430  Mood Disorder (Depression, Bipolar Disorder, etc)
# 1431           Attention Deficit Hyperactivity Disorder
# 1432                                                NaN
#
# [1433 rows x 8 columns]

# %% [markdown]
# # Null Values

# %%
data.isnull() \
    .sum() \
    .sort_values(ascending = False)
# Out:
# conditions             865
# number_of_employees    287
# gender                   3
# survey_date              0
# age                      0
# self_employed            0
# years_employed           0
# has_mental_health        0
# dtype: int64

# %%
data[data['number_of_employees'].isnull()]
# Out:
#      survey_date age gender  self_employed  years_employed  \
# 4     2022-01-01  34   Male           True            9.92
# 7     2022-01-01  39   Male           True           12.52
# 33    2022-01-01  37   Male           True           17.47
# 34    2022-01-01  25   Male           True           10.51
# 36    2022-01-01  43      M           True           20.98
# ...          ...  ..    ...            ...             ...
# 1413  2022-01-10  39   Male           True            4.59
# 1419  2022-01-10  26      M           True           10.10
# 1420  2022-01-10  29   male           True            2.54
# 1426  2022-01-10  31   male           True            1.99
# 1432  2022-01-10  56   MALE           True           21.20
#
#      number_of_employees has_mental_health  \
# 4                    NaN               Yes
# 7                    NaN                No
# 33                   NaN               Yes
# 34                   NaN                No
# 36                   NaN                No
# ...                  ...               ...
# 1413                 NaN               Yes
# 1419                 NaN             Maybe
# 1420                 NaN                No
# 1426                 NaN                No
# 1432                 NaN                No
#
#                                              conditions
# 4     Mood Disorder (Depression, Bipolar Disorder, e...
# 7                                                   NaN
# 33                                           Depression
# 34                                                  NaN
# 36                                                  NaN
# ...                                                 ...
# 1413  Mood Disorder (Depression, Bipolar Disorder, e...
# 1419                                                NaN
# 1420                                                NaN
# 1426                                                NaN
# 1432                                                NaN
#
# [287 rows x 8 columns]

# %%
# COULD REMOVE ROWS FOR GENDER, COLUMN FOR CONDITIONS SINCE MAJORITY NULL AND KEEP NUMBER OF EMPLOYEES (INPUTE SELF EMPLOYED THERE)

# %% [markdown]
# # Detect Outliers with Functions

# %% [markdown]
# Functions must be indented using the TAB key, otherwise they will not work.
#
# "def" for define
#
# Format:
# ```
# def function_name(input1, ..., inputx):
#   {code}
#   return {output}
# ```

# %%
def multiply(x, y):
    result = x * y
    return result

# %%
multiply(5, 10)
# Out:
# 50

# %%
data.groupby('survey_date') \
    .size() \
    .sort_values(ascending = False)
# Out:
# survey_date
# 2022-01-02    144
# 2022-01-03    144
# 2022-01-04    143
# 2022-01-05    143
# 2022-01-06    143
# 2022-01-07    143
# 2022-01-08    143
# 2022-01-09    143
# 2022-01-10    143
# 2022-01-01    138
# 2025-06-01      5
# 2023-05-01      1
# dtype: int64

# %%
def my_counter(column):
    result = data.groupby(column, dropna = False) \
                 .size() \
                 .sort_values(ascending = False)
    return result

# %%
my_counter(['survey_date'])
# Out:
# survey_date
# 2022-01-02    144
# 2022-01-03    144
# 2022-01-04    143
# 2022-01-05    143
# 2022-01-06    143
# 2022-01-07    143
# 2022-01-08    143
# 2022-01-09    143
# 2022-01-10    143
# 2022-01-01    138
# 2025-06-01      5
# 2023-05-01      1
# dtype: int64

# %% [markdown]
# # Fixing Outliers with Conditional Filtering

# %% [markdown]
# 1) Null the value
# 2) remove the row
# 3) remove the column
# 4) fill with value (previous, mean, median, etc..) but only if appropriate

# %% [markdown]
# ## Survey Date

# %%
data[(data['survey_date'] == '2025-06-01') | (data['survey_date'] == '2023-05-01')]
# Out:
#     survey_date age  gender  self_employed  years_employed  \
# 31   2025-06-01  32  Female          False           19.21
# 37   2025-06-01  35  Female          False            5.23
# 45   2025-06-01  40    Male           True           10.10
# 53   2023-05-01  22    Male           True            9.34
# 88   2025-06-01  31  Female          False            6.33
# 140  2025-06-01  28  female          False            4.67
#
#      number_of_employees has_mental_health  \
# 31   2025-06-01 00:00:00               Yes
# 37              500-1000                No
# 45                   NaN                No
# 53                   NaN             Maybe
# 88   2025-06-01 00:00:00             Maybe
# 140  2025-06-01 00:00:00             Maybe
#
#                                             conditions
# 31   Anxiety Disorder (Generalized, Social, Phobia,...
# 37                                                 NaN
# 45                                                 NaN
# 53                                                 NaN
# 88                                                 NaN
# 140                                                NaN

# %%
data['survey_date'][[30, 36, 44, 52, 87, 139]]
# Out:
# 30    2022-01-01
# 36    2022-01-01
# 44    2022-01-01
# 52    2022-01-01
# 87    2022-01-01
# 139   2022-01-01
# Name: survey_date, dtype: datetime64[ns]

# %%
data.loc[(data['survey_date'] == '2025-06-01') | (data['survey_date'] == '2023-05-01'), 'survey_date'] = '2022-01-01'

# %%
data[data.index == 31]
# Out:
#    survey_date age  gender  self_employed  years_employed  \
# 31  2022-01-01  32  Female          False           19.21
#
#     number_of_employees has_mental_health  \
# 31  2025-06-01 00:00:00               Yes
#
#                                            conditions
# 31  Anxiety Disorder (Generalized, Social, Phobia,...

# %% [markdown]
# ## Age

# %%
my_counter('age')
# Out:
# age
# 30             94
# 31             82
# 29             78
# 28             74
# 35             74
# 32             72
# 34             69
# 33             69
# 26             64
# 27             63
# 37             59
# 39             55
# 38             54
# 36             49
# 25             44
# 24             42
# 40             36
# 22             32
# 44             31
# 42             29
# 43             29
# 45             27
# 23             24
# 41             24
# 46             22
# 21             15
# 47             14
# 49             13
# 55             12
# 48              9
# 50              9
# 52              7
# 54              7
# 51              7
# 20              6
# 56              5
# 57              4
# 63              4
# 19              4
# 53              3
# 59              2
# 61              2
# thirty six      1
# 99              1
# 66              1
# 74              1
# 70              1
# forty three     1
# 15              1
# 65              1
# 62              1
# 58              1
# 17              1
# 323             1
# 3               1
# twenty nine     1
# dtype: int64

# %%
data[data['age'].isin(['thirty six', 'forty three', 'twenty nine'])]
# Out:
#     survey_date          age  gender  self_employed  years_employed  \
# 77   2022-01-01  twenty nine       M          False            2.14
# 103  2022-01-01  forty three  Female          False            4.03
# 152  2022-01-02   thirty six    Male          False           15.20
#
#      number_of_employees has_mental_health  \
# 77                26-100                No
# 103       More than 1000                No
# 152  2023-05-01 00:00:00               Yes
#
#                                             conditions
# 77                                                 NaN
# 103                                                NaN
# 152  Anxiety Disorder (Generalized, Social, Phobia,...

# %%
numbers = {
  'thirty six': 36,
  'forty three': 43, 
  'twenty nine': 29
}

# %%
data = data.replace({'age': numbers})

# %%
data['age'] = data['age'].astype(int)

# %%
data[(data['age'] <= 18) | (data['age'] >= 80)]
# Out:
#      survey_date  age gender  self_employed  years_employed  \
# 325   2022-01-03   99  Other          False            2.44
# 441   2022-01-04   17   male          False            9.40
# 631   2022-01-05  323   Male          False           19.65
# 926   2022-01-07    3   Male          False           12.84
# 1227  2022-01-09   15   male           True            5.47
#
#       number_of_employees has_mental_health              conditions
# 325   2025-06-01 00:00:00               Yes  Traumatic Brain Injury
# 441   2025-06-01 00:00:00                No                     NaN
# 631               100-500                No                     NaN
# 926        More than 1000             Maybe                     NaN
# 1227                  NaN                No                     NaN

# %%
data.loc[(data['age'] <= 16) | (data['age'] >= 100), 'age'] = data['age'].mean().astype(int)

# %%
data[data.index == 631]
# Out:
#     survey_date  age gender  self_employed  years_employed  \
# 631  2022-01-05   34   Male          False           19.65
#
#     number_of_employees has_mental_health conditions
# 631             100-500                No        NaN

# %% [markdown]
# ## Gender

# %%
data['gender'] = data['gender'].str.lower()

male = ['Male', 'male', 'M', 'm', 'Cis Male', 'man', 'ostensibly male, unsure what that really means', 'Mail', 'Make', 'male (cis)', 
        'cis male', 'maile', 'Malr', 'Cis Man', 'Mal', 'msle', 'male.', 'sex is male', 'malr', 'cis man', 'mail' ]
     
female = ['Female', 'female', 'F', 'f', 'Woman', 'Femake', 'Female (cis)', 'cis female', 'woman', 'femail', 
     'cis-female/femme', 'i identify as female.', 'cis-woman', 'cisgender female', 'female (props for making this a freeform field, though)', 
     'female/woman', 'female assigned at birth' ]

other = list(data['gender'].value_counts().index)[2:]

data.loc[data['gender'].isin(male), 'gender'] = 'male'
data.loc[data['gender'].isin(female), 'gender'] = 'female'
data.loc[data['gender'].isin(other), 'gender'] = 'others'

# %%
my_counter('gender')
# Out:
# gender
# male      1040
# female     321
# others      69
# NaN          3
# dtype: int64

# %%
data[data['gender'].isnull()]
# Out:
#     survey_date  age gender  self_employed  years_employed  \
# 318  2022-01-03   24    NaN          False           21.07
# 419  2022-01-03   26    NaN          False            0.21
# 496  2022-01-04   25    NaN          False            5.56
#
#     number_of_employees has_mental_health  \
# 318      More than 1000               Yes
# 419             100-500               Yes
# 496              26-100               Yes
#
#                                             conditions
# 318  Mood Disorder (Depression, Bipolar Disorder, e...
# 419  Anxiety Disorder (Generalized, Social, Phobia,...
# 496  Anxiety Disorder (Generalized, Social, Phobia,...

# %% [markdown]
# ## Self Employed Flag

# %%
my_counter('self_employed')
# Out:
# self_employed
# False    1146
# True      287
# dtype: int64

# %%
my_counter(['self_employed', 'number_of_employees'])
# Out:
# self_employed  number_of_employees
# False          26-100                 292
# True           NaN                    287
# False          More than 1000         256
#                100-500                248
#                2025-06-01 00:00:00    210
#                500-1000                80
#                2023-05-01 00:00:00     60
# dtype: int64

# %% [markdown]
# ## Number of Employees

# %%
categories = ['26-100', '100-500', '500-1000']
data.loc[~(data['number_of_employees'].isin(categories)), 'number_of_employees'] = None

# %%
my_counter('number_of_employees')
# Out:
# number_of_employees
# NaN         813
# 26-100      292
# 100-500     248
# 500-1000     80
# dtype: int64

# %% [markdown]
# ## Has Mental Health Flag

# %%
my_counter('has_mental_health')
# Out:
# has_mental_health
# Yes      575
# No       531
# Maybe    327
# dtype: int64

# %%
data[(data['has_mental_health'] == 'Yes') & (data['conditions'].isnull())]
# Out:
#      survey_date  age  gender  self_employed  years_employed  \
# 169   2022-01-02   45  female          False            7.33
# 461   2022-01-04   34    male           True           18.98
# 591   2022-01-05   21    male          False           22.20
# 632   2022-01-05   35  female          False           18.17
# 781   2022-01-06   33    male          False            4.66
# 808   2022-01-06   40  female          False           22.54
# 1395  2022-01-10   27    male          False           13.79
#
#      number_of_employees has_mental_health conditions
# 169             500-1000               Yes        NaN
# 461                 None               Yes        NaN
# 591                 None               Yes        NaN
# 632              100-500               Yes        NaN
# 781              100-500               Yes        NaN
# 808                 None               Yes        NaN
# 1395                None               Yes        NaN

# %%
data['conditions'] = data['conditions'].str.split('|')

# %%
data_conditions = data.explode('conditions')
