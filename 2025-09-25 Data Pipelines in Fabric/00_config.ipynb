# %%
config = {
    "lakehouse_name": "coffee_lakehouse",
    "lakehouse_path": "abfss://490a35a8-ffa1-4c26-8ad2-f394ba2aaefd@onelake.dfs.fabric.microsoft.com/e5d53df5-727e-4244-8a8e-eb9d9b6ac78b/Tables"
}
